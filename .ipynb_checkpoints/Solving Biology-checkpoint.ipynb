# %%
"""
NOTES:

Biology and Computer Science 

  -connection between them.
  

What is biology?

Subject and part of science that is trying to understand and describe life on the world.

most basic unit of biology is cell.
prokaryotic and eukaryotic cells.

basic needs for every cell to exist:
  
  cytoplaysm;
  DNA;
  ribosomes;
  
//if prokaryotic cell , 16 bit max.

struct ribosome{
    uint8_t down;
    uint8_t up;
    void* IRNA_address;
};
struct PCell{
    uint16_t cytoplasm;
    uint16_t DNA[3][2];//DNA is a two molecule oriented acid .
    struct ribosome[4];
};

so as geohot said, we can treat these things very differently.
So you can say that DNA could be a unique hash of every human.

goal of this project is to do cell division (replicate every process that cell needs to do here, just computer science way.)
we are doing fission division (thanks teacher for learning me what it is )

that means we are targeting prokarytoic cells.

what is happening here?

DNA is first being replicated.
then our cytoplasm is getting larger and gap is getting bigger ( so basically, we are creating new objects here and putting old values from dna here)

when he shares our new values , he will also share IRNA. so we gotta read all the values from ribosomes and put them here.
"""
import os,io,sys
import torch
import numpy as np
import random

class PCell(object):
   
    def __init__(self,irna):
        self.irna =irna
        self.ribosome=None
        self.dna=[]
        self.cytoplasm=[]
        print("*** pcell is here. i'm abouta create a new pandemic.")
    
    def create_unique_dna(self):
        print("h")

IRNA_SIZE = 1024
def init_irna():
    irna=[]
    for i in range(IRNA_SIZE):
        irna.append(np.random.uniform(0.0,1))
        
    return irna
    
irna = init_irna()
c1 = PCell(irna)
# Out:
# [0.242505735307458, 0.9722590498207737, 0.9720309309044618, 0.7467638687391391, 0.17942512148930045, 0.845741367172617, 0.4128121976369159, 0.95415277866787, 0.8520908270076073, 0.7078420952807144, 0.5475899774270289, 0.025421642964739477, 0.07984284626932414, 0.7723642245843345, 0.6114184112913688, 0.18373828193545083, 0.852814514502428, 0.7414271483693091, 0.44750657280641637, 0.4176969512961769, 0.9868928352901045, 0.15509931086285111, 0.5578004825499734, 0.09603062688504416, 0.8108964724197468, 0.9654551929934188, 0.12409917108582558, 0.3657121441630866, 0.3898814566220097, 0.6601542981155955, 0.5317267288324955, 0.7827709790787011, 0.200091628528406, 0.7861437513862388, 0.5827104435349326, 0.8921950264551589, 0.09827281903266594, 0.9005495546641783, 0.7986685498837002, 0.788137246414515, 0.041721258940252914, 0.10239017157901875, 0.9081427951878669, 0.3988306882084959, 0.06227295438680136, 0.7126621854790107, 0.46486675349611173, 0.6713985628844272, 0.6480328544028626, 0.17152689402713062, 0.8052123647799931, 0.7801135906795119, 0.6611119027438234, 0.1901326074025158, 0.11104032107741713, 0.7574256804159151, 0.643385403434286, 0.13451654081523834, 0.999132517039674, 0.19883957195986568, 0.6301227240077751, 0.2863937597050311, 0.38757339955819436, 0.21968125191378862, 0.022528307788